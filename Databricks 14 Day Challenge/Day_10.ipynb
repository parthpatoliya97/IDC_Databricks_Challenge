# %%
spark.sql("""
SELECT *
FROM ecommerce.silver.silver_events
WHERE event_type = 'purchase'
""").explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Project [*]
# +- 'Filter ('event_type = purchase)
#    +- 'UnresolvedRelation [ecommerce, silver, silver_events], [], false
#
# == Analyzed Logical Plan ==
# event_time: timestamp, event_type: string, product_id: int, category_id: bigint, category_code: string, brand: string, price: double, user_id: int, user_session: string
# Project [event_time#13189, event_type#13190, product_id#13191, category_id#13192L, category_code#13193, brand#13194, price#13195, user_id#13196, user_session#13197]
# +- Filter (event_type#13190 = purchase)
#    +- SubqueryAlias ecommerce.silver.silver_events
#       +- Relation ecommerce.silver.silver_events[event_time#13189,event_type#13190,product_id#13191,category_id#13192L,category_code#13193,brand#13194,price#13195,user_id#13196,user_session#13197] parquet
#
# == Optimized Logical Plan ==
# Filter (isnotnull(event_type#13190) AND (event_type#13190 = purchase))
# +- Relation ecommerce.silver.silver_events[event_time#13189,event_type#13190,product_id#13191,category_id#13192L,category_code#13193,brand#13194,price#13195,user_id#13196,user_session#13197] parquet
#
# == Physical Plan ==
# *(1) ColumnarToRow
# +- PhotonResultStage
#    +- PhotonScan parquet ecommerce.silver.silver_events[event_time#13189,event_type#13190,product_id#13191,category_id#13192L,category_code#13193,brand#13194,price#13195,user_id#13196,user_session#13197] DataFilters: [isnotnull(event_type#13190), (event_type#13190 = purchase)], DictionaryFilters: [(event_type#13190 = purchase)], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://dbstorage-prod-qjnih/uc/ffed3f4b-55c4-4381-8061-7fadc830f64f..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<event_time:timestamp,event_type:string,product_id:int,category_id:bigint,category_code:str..., RequiredDataFilters: [isnotnull(event_type#13190), (event_type#13190 = purchase)]
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial =
#   full    = silver_events

# %%
# %sql
CREATE TABLE ecommerce.silver.silver_events_part
USING DELTA
PARTITIONED BY (event_date, event_type)
AS
SELECT
  DATE(event_time) AS event_date,
  *
FROM ecommerce.silver.silver_events;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
OPTIMIZE ecommerce.silver.silver_events_part;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 182, null, null, 0, 0, 182, 182, true, 0, 0, 1768715255649, 1768715257211, 8, 0, null, List(0, 0), null, 10, 10, 0, 0, null)</td></tr></tbody></table></div>

# %%
# %sql
OPTIMIZE ecommerce.silver.silver_events_part
ZORDER BY (user_id, product_id);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(13, 4, List(38075521, 95346450, 4.9423521384615384E7, 13, 642505778), List(96484052, 202499967, 1.71385253E8, 4, 685541012), 182, List(minCubeSize(107374182400), List(0, 0), List(182, 3631957718), 0, List(4, 685541012), 4, null), null, 0, 1, 182, 178, false, 0, 0, 1768715285577, 1768715309663, 8, 4, null, List(0, 0), null, 10, 10, 37430, 0, null)</td></tr></tbody></table></div>

# %%
import time

start = time.time()
spark.sql("""
SELECT *
FROM ecommerce.silver.silver_events
WHERE user_id = 12345
""").count()
print(f"Time before: {time.time() - start:.2f}s")
# Out:
# Time before: 1.01s

# %%
start = time.time()
spark.sql("""
SELECT *
FROM ecommerce.silver.silver_events_part
WHERE user_id = 12345
""").count()
print(f"Time after: {time.time() - start:.2f}s")
# Out:
# Time after: 0.76s

# %%
cached_df = spark.table("ecommerce.silver.silver_events_part")
cached_df.count()  # materialize cache
# Out:
# 109819992

# %%
# %sql
SELECT COUNT(*) FROM ecommerce.silver.silver_events_part WHERE event_type='purchase';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>1659703</td></tr></tbody></table></div>

# %%
import time

query_before = """
SELECT
  brand,
  ROUND(SUM(price), 2) AS total_revenue
FROM ecommerce.silver.silver_events
WHERE event_type = 'purchase'
  AND brand IS NOT NULL
GROUP BY brand
ORDER BY total_revenue DESC
LIMIT 10
"""

start = time.time()
spark.sql(query_before).collect()
print(f"Before Optimization Time: {time.time() - start:.2f} seconds")
# Out:
# Before Optimization Time: 2.30 seconds

# %%
spark.sql(query_before).explain(True)
# Out:
# == Parsed Logical Plan ==
# 'GlobalLimit 10
# +- 'LocalLimit 10
#    +- 'Sort ['total_revenue DESC NULLS LAST], true
#       +- 'Aggregate ['brand], ['brand, 'ROUND('SUM('price), 2) AS total_revenue#18564]
#          +- 'Filter (('event_type = purchase) AND isnotnull('brand))
#             +- 'UnresolvedRelation [ecommerce, silver, silver_events], [], false
#
# == Analyzed Logical Plan ==
# brand: string, total_revenue: double
# GlobalLimit 10
# +- LocalLimit 10
#    +- Sort [total_revenue#18564 DESC NULLS LAST], true
#       +- Aggregate [brand#18579], [brand#18579, round(sum(price#18580), 2) AS total_revenue#18564]
#          +- Filter ((event_type#18575 = purchase) AND isnotnull(brand#18579))
#             +- SubqueryAlias ecommerce.silver.silver_events
#                +- Relation ecommerce.silver.silver_events[event_time#18574,event_type#18575,product_id#18576,category_id#18577L,category_code#18578,brand#18579,price#18580,user_id#18581,user_session#18582] parquet
#
# == Optimized Logical Plan ==
# GlobalLimit 10
# +- LocalLimit 10
#    +- Sort [total_revenue#18564 DESC NULLS LAST], true
#       +- Aggregate [brand#18579], [brand#18579, round(sum(price#18580), 2) AS total_revenue#18564]
#          +- Project [brand#18579, price#18580]
#             +- Filter ((isnotnull(event_type#18575) AND isnotnull(brand#18579)) AND (event_type#18575 = purchase))
#                +- Relation ecommerce.silver.silver_events[event_time#18574,event_type#18575,product_id#18576,category_id#18577L,category_code#18578,brand#18579,price#18580,user_id#18581,user_session#18582] parquet
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonTopK(limit=10, includeTies=false, sortOrder=[total_revenue#18564 DESC NULLS LAST], partitionOrderCount=0)
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#11321]
#                +- PhotonShuffleExchangeSink SinglePartition
#                   +- PhotonTopK(limit=10, includeTies=false, sortOrder=[total_revenue#18564 DESC NULLS LAST], partitionOrderCount=0)
#                      +- PhotonGroupingAgg(limit=None, keys=[brand#18579], functions=[finalmerge_sum(merge sum#18602) AS sum(price)#18583], output=[brand#18579, total_revenue#18564])
#                         +- PhotonShuffleExchangeSource
#                            +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#11313]
#                               +- PhotonShuffleExchangeSink hashpartitioning(brand#18579, 1024)
#                                  +- PhotonGroupingAgg(limit=None, keys=[brand#18579], functions=[partial_sum(price#18580) AS sum#18602], output=[brand#18579, sum#18602])
#                                     +- PhotonProject [brand#18579, price#18580]
#                                        +- PhotonScan parquet ecommerce.silver.silver_events[event_type#18575,brand#18579,price#18580] DataFilters: [isnotnull(event_type#18575), isnotnull(brand#18579), (event_type#18575 = purchase)], DictionaryFilters: [(event_type#18575 = purchase)], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://dbstorage-prod-qjnih/uc/ffed3f4b-55c4-4381-8061-7fadc830f64f..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<event_type:string,brand:string,price:double>, RequiredDataFilters: [isnotnull(event_type#18575), isnotnull(brand#18579), (event_type#18575 = purchase)]
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial =
#   full    = silver_events

# %%
query_after = """
SELECT
  brand,
  ROUND(SUM(price), 2) AS total_revenue
FROM ecommerce.silver.silver_events_part
WHERE event_type = 'purchase'
  AND brand IS NOT NULL
GROUP BY brand
ORDER BY total_revenue DESC
LIMIT 10
"""

start = time.time()
spark.sql(query_after).collect()
print(f"After Optimization Time: {time.time() - start:.2f} seconds")
# Out:
# After Optimization Time: 1.42 seconds

# %%
spark.sql(query_after).explain(True)
# Out:
# == Parsed Logical Plan ==
# 'GlobalLimit 10
# +- 'LocalLimit 10
#    +- 'Sort ['total_revenue DESC NULLS LAST], true
#       +- 'Aggregate ['brand], ['brand, 'ROUND('SUM('price), 2) AS total_revenue#18737]
#          +- 'Filter (('event_type = purchase) AND isnotnull('brand))
#             +- 'UnresolvedRelation [ecommerce, silver, silver_events_part], [], false
#
# == Analyzed Logical Plan ==
# brand: string, total_revenue: double
# GlobalLimit 10
# +- LocalLimit 10
#    +- Sort [total_revenue#18737 DESC NULLS LAST], true
#       +- Aggregate [brand#18754], [brand#18754, round(sum(price#18755), 2) AS total_revenue#18737]
#          +- Filter ((event_type#18750 = purchase) AND isnotnull(brand#18754))
#             +- SubqueryAlias ecommerce.silver.silver_events_part
#                +- Relation ecommerce.silver.silver_events_part[event_date#18748,event_time#18749,event_type#18750,product_id#18751,category_id#18752L,category_code#18753,brand#18754,price#18755,user_id#18756,user_session#18757] parquet
#
# == Optimized Logical Plan ==
# GlobalLimit 10
# +- LocalLimit 10
#    +- Sort [total_revenue#18737 DESC NULLS LAST], true
#       +- Aggregate [brand#18754], [brand#18754, round(sum(price#18755), 2) AS total_revenue#18737]
#          +- Project [brand#18754, price#18755]
#             +- Filter ((isnotnull(event_type#18750) AND isnotnull(brand#18754)) AND (event_type#18750 = purchase))
#                +- Relation ecommerce.silver.silver_events_part[event_date#18748,event_time#18749,event_type#18750,product_id#18751,category_id#18752L,category_code#18753,brand#18754,price#18755,user_id#18756,user_session#18757] parquet
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonTopK(limit=10, includeTies=false, sortOrder=[total_revenue#18737 DESC NULLS LAST], partitionOrderCount=0)
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#11700]
#                +- PhotonShuffleExchangeSink SinglePartition
#                   +- PhotonTopK(limit=10, includeTies=false, sortOrder=[total_revenue#18737 DESC NULLS LAST], partitionOrderCount=0)
#                      +- PhotonGroupingAgg(limit=None, keys=[brand#18754], functions=[finalmerge_sum(merge sum#18775) AS sum(price)#18758], output=[brand#18754, total_revenue#18737])
#                         +- PhotonShuffleExchangeSource
#                            +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#11692]
#                               +- PhotonShuffleExchangeSink hashpartitioning(brand#18754, 1024)
#                                  +- PhotonGroupingAgg(limit=None, keys=[brand#18754], functions=[partial_sum(price#18755) AS sum#18775], output=[brand#18754, sum#18775])
#                                     +- PhotonProject [brand#18754, price#18755]
#                                        +- PhotonScan parquet ecommerce.silver.silver_events_part[brand#18754,price#18755,event_date#18748,event_type#18750] DataFilters: [isnotnull(brand#18754)], DictionaryFilters: [], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://dbstorage-prod-qjnih/uc/ffed3f4b-55c4-4381-8061-7fadc830f64f..., OptionalDataFilters: [], PartitionFilters: [isnotnull(event_type#18750), (event_type#18750 = purchase)], ReadSchema: struct<brand:string,price:double>, RequiredDataFilters: [isnotnull(brand#18754)]
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial =
#   full    = silver_events_part
