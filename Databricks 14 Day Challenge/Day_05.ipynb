# %%
from pyspark.sql import types as T

data = [
    (1, "Asha", "IN", 100.0),
    (2, "Bob",  "US", 200.0),
    (3, "Chen", "CN", 150.0)
]

schema = T.StructType([
    T.StructField("order_id", T.IntegerType(), False),
    T.StructField("customer", T.StringType(), True),
    T.StructField("country",  T.StringType(), True),
    T.StructField("amount",   T.DoubleType(), True)
])

df = spark.createDataFrame(data, schema)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer</th><th>country</th><th>amount</th></tr></thead><tbody><tr><td>1</td><td>Asha</td><td>IN</td><td>100.0</td></tr><tr><td>2</td><td>Bob</td><td>US</td><td>200.0</td></tr><tr><td>3</td><td>Chen</td><td>CN</td><td>150.0</td></tr></tbody></table></div>

# %%
df.write \
  .format("delta") \
  .mode("overwrite") \
  .saveAsTable("orders_delta")

# %%
# %sql
SELECT * FROM orders_delta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer</th><th>country</th><th>amount</th></tr></thead><tbody><tr><td>1</td><td>Asha</td><td>IN</td><td>100.0</td></tr><tr><td>2</td><td>Bob</td><td>US</td><td>200.0</td></tr><tr><td>3</td><td>Chen</td><td>CN</td><td>150.0</td></tr></tbody></table></div>

# %%
# %sql
UPDATE orders_delta
SET amount = 250
WHERE order_id = 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
INSERT INTO orders_delta
VALUES (4, 'Diana', 'US', 300.0);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE HISTORY orders_delta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>3</td><td>2026-01-13T05:01:25.000Z</td><td>77838657344022</td><td>parthpatoliya001@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> true, partitionBy -> [])</td><td>null</td><td>List(3660372887555348)</td><td>0113-044657-w8zxg0uu-v2n</td><td>2</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1186)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>2</td><td>2026-01-13T05:01:11.000Z</td><td>77838657344022</td><td>parthpatoliya001@gmail.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> true, clusterBy -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td><td>List(3660372887555348)</td><td>0113-044657-w8zxg0uu-v2n</td><td>1</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 2, numRemovedBytes -> 2447, p25FileSize -> 1257, numDeletionVectorsRemoved -> 1, minFileSize -> 1257, numAddedFiles -> 1, maxFileSize -> 1257, p75FileSize -> 1257, p50FileSize -> 1257, numAddedBytes -> 1257)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>1</td><td>2026-01-13T05:01:09.000Z</td><td>77838657344022</td><td>parthpatoliya001@gmail.com</td><td>UPDATE</td><td>Map(predicate -> ["(order_id#13530 = 2)"])</td><td>null</td><td>List(3660372887555348)</td><td>0113-044657-w8zxg0uu-v2n</td><td>0</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 3519, numDeletionVectorsUpdated -> 0, scanTimeMs -> 1642, numAddedFiles -> 1, numUpdatedRows -> 1, numAddedBytes -> 1200, rewriteTimeMs -> 1856)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>0</td><td>2026-01-13T05:00:29.000Z</td><td>77838657344022</td><td>parthpatoliya001@gmail.com</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"delta.enableDeletionVectors":"true"}, statsOnLoad -> true)</td><td>null</td><td>List(3660372887555348)</td><td>0113-044657-w8zxg0uu-v2n</td><td>null</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 1, numRemovedFiles -> 0, numRemovedBytes -> 0, numDeletionVectorsRemoved -> 0, numOutputRows -> 3, numOutputBytes -> 1247)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM orders_delta VERSION AS OF 0;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer</th><th>country</th><th>amount</th></tr></thead><tbody><tr><td>1</td><td>Asha</td><td>IN</td><td>100.0</td></tr><tr><td>2</td><td>Bob</td><td>US</td><td>200.0</td></tr><tr><td>3</td><td>Chen</td><td>CN</td><td>150.0</td></tr></tbody></table></div>

# %%
updates = [
    (2, "Bob", "US", 220.0),   # update
    (5, "Eva", "UK", 180.0)    # insert
]
df_updates = spark.createDataFrame(updates, schema)
display(df_updates)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer</th><th>country</th><th>amount</th></tr></thead><tbody><tr><td>2</td><td>Bob</td><td>US</td><td>220.0</td></tr><tr><td>5</td><td>Eva</td><td>UK</td><td>180.0</td></tr></tbody></table></div>

# %%
df_updates.createOrReplaceTempView("df_updates")

# %%
# %sql
MERGE INTO orders_delta t
USING df_updates s
ON t.order_id = s.order_id
WHEN MATCHED THEN
  UPDATE SET *
WHEN NOT MATCHED THEN
  INSERT *;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>1</td><td>0</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM orders_delta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer</th><th>country</th><th>amount</th></tr></thead><tbody><tr><td>1</td><td>Asha</td><td>IN</td><td>100.0</td></tr><tr><td>3</td><td>Chen</td><td>CN</td><td>150.0</td></tr><tr><td>4</td><td>Diana</td><td>US</td><td>300.0</td></tr><tr><td>2</td><td>Bob</td><td>US</td><td>220.0</td></tr><tr><td>5</td><td>Eva</td><td>UK</td><td>180.0</td></tr></tbody></table></div>

# %%
# %sql
OPTIMIZE orders_delta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, null, null, 0, 0, 1, 1, true, 0, 0, 1768281116346, 1768281116911, 8, 0, null, List(0, 0), null, 4, 4, 0, 0, null)</td></tr></tbody></table></div>

# %%
# %sql
OPTIMIZE orders_delta
ZORDER BY (country);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, List(minCubeSize(107374182400), List(0, 0), List(1, 1326), 0, List(0, 0), 0, null), null, 0, 0, 1, 1, false, 0, 0, 1768281138674, 1768281139176, 8, 0, null, List(0, 0), null, 4, 4, 0, 0, null)</td></tr></tbody></table></div>

# %%
# %sql
VACUUM orders_delta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td></td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM orders_delta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer</th><th>country</th><th>amount</th></tr></thead><tbody><tr><td>1</td><td>Asha</td><td>IN</td><td>100.0</td></tr><tr><td>3</td><td>Chen</td><td>CN</td><td>150.0</td></tr><tr><td>4</td><td>Diana</td><td>US</td><td>300.0</td></tr><tr><td>2</td><td>Bob</td><td>US</td><td>220.0</td></tr><tr><td>5</td><td>Eva</td><td>UK</td><td>180.0</td></tr></tbody></table></div>
